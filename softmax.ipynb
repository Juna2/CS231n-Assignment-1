# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.306368
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *처음에는 weight이 0에 가깝게 초기화되었기 때문에 normalize한 값이 0.1이 나온다.*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 4.609689 analytic: 4.609689, relative error: 7.179985e-09
# numerical: 3.192113 analytic: 3.192113, relative error: 5.356584e-09
# numerical: -3.037093 analytic: -3.037093, relative error: 5.238488e-09
# numerical: 0.796164 analytic: 0.796164, relative error: 1.888530e-08
# numerical: 1.932440 analytic: 1.932440, relative error: 3.933558e-08
# numerical: -0.043499 analytic: -0.043499, relative error: 4.645436e-08
# numerical: -3.273555 analytic: -3.273555, relative error: 7.611523e-09
# numerical: 1.113335 analytic: 1.113335, relative error: 1.825066e-08
# numerical: -3.558300 analytic: -3.558300, relative error: 3.994007e-09
# numerical: 1.695710 analytic: 1.695710, relative error: 2.387628e-08
# numerical: -0.925706 analytic: -0.925706, relative error: 4.626307e-08
# numerical: 1.852845 analytic: 1.852845, relative error: 8.353244e-10
# numerical: 2.118249 analytic: 2.118249, relative error: 3.299704e-08
# numerical: -0.930023 analytic: -0.930023, relative error: 1.582931e-08
# numerical: -0.561866 analytic: -0.561866, relative error: 9.288276e-08
# numerical: 2.005716 analytic: 2.005716, relative error: 2.706314e-09
# numerical: 0.107204 analytic: 0.107204, relative error: 1.669429e-07
# numerical: -0.976353 analytic: -0.976353, relative error: 8.495076e-08
# numerical: 1.605023 analytic: 1.605023, relative error: 1.021696e-08
# numerical: 2.131106 analytic: 2.131106, relative error: 1.351269e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.306368e+00 computed in 0.293665s
# vectorized loss: 2.306368e+00 computed in 0.038075s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
lr_test = np.linspace(1e-7, 5e-7, 10)
rs_test = np.linspace(2.5e4, 5e4, 10)

for i in range(10):
    for j in range(10):
        softmax_test = Softmax()
        
        _ = softmax_test.train(X_train, y_train, learning_rate=lr_test[i],
                                    reg=rs_test[j], num_iters=1000, verbose=False)
        _ = softmax_test.train(X_val, y_val, learning_rate=lr_test[i],
                                  reg=rs_test[j], num_iters=1000, verbose=False)
        
        y_train_pred = softmax_test.predict(X_train)
        y_val_pred = softmax_test.predict(X_val)
        
        train_acc = np.mean(y_train_pred == y_train)
        val_acc = np.mean(y_val_pred == y_val)
        
        if val_acc > best_val:
            best_val = val_acc
            best_softmax = softmax_test
        
        results[(lr_test[i], rs_test[j])] = \
                            (train_acc, val_acc)
        
        print('(%d, %d) finished' %(i, j))
            
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# (0, 0) finished
# (0, 1) finished
# (0, 2) finished
# (0, 3) finished
# (0, 4) finished
# (0, 5) finished
# (0, 6) finished
# (0, 7) finished
# (0, 8) finished
# (0, 9) finished
# (1, 0) finished
# (1, 1) finished
# (1, 2) finished
# (1, 3) finished
# (1, 4) finished
# (1, 5) finished
# (1, 6) finished
# (1, 7) finished
# (1, 8) finished
# (1, 9) finished
# (2, 0) finished
# (2, 1) finished
# (2, 2) finished
# (2, 3) finished
# (2, 4) finished
# (2, 5) finished
# (2, 6) finished
# (2, 7) finished
# (2, 8) finished
# (2, 9) finished
# (3, 0) finished
# (3, 1) finished
# (3, 2) finished
# (3, 3) finished
# (3, 4) finished
# (3, 5) finished
# (3, 6) finished
# (3, 7) finished
# (3, 8) finished
# (3, 9) finished
# (4, 0) finished
# (4, 1) finished
# (4, 2) finished
# (4, 3) finished
# (4, 4) finished
# (4, 5) finished
# (4, 6) finished
# (4, 7) finished
# (4, 8) finished
# (4, 9) finished
# (5, 0) finished
# (5, 1) finished
# (5, 2) finished
# (5, 3) finished
# (5, 4) finished
# (5, 5) finished
# (5, 6) finished
# (5, 7) finished
# (5, 8) finished
# (5, 9) finished
# (6, 0) finished
# (6, 1) finished
# (6, 2) finished
# (6, 3) finished
# (6, 4) finished
# (6, 5) finished
# (6, 6) finished
# (6, 7) finished
# (6, 8) finished
# (6, 9) finished
# (7, 0) finished
# (7, 1) finished
# (7, 2) finished
# (7, 3) finished
# (7, 4) finished
# (7, 5) finished
# (7, 6) finished
# (7, 7) finished
# (7, 8) finished
# (7, 9) finished
# (8, 0) finished
# (8, 1) finished
# (8, 2) finished
# (8, 3) finished
# (8, 4) finished
# (8, 5) finished
# (8, 6) finished
# (8, 7) finished
# (8, 8) finished
# (8, 9) finished
# (9, 0) finished
# (9, 1) finished
# (9, 2) finished
# (9, 3) finished
# (9, 4) finished
# (9, 5) finished
# (9, 6) finished
# (9, 7) finished
# (9, 8) finished
# (9, 9) finished
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.303000 val accuracy: 0.397000
# lr 1.000000e-07 reg 2.777778e+04 train accuracy: 0.299429 val accuracy: 0.391000
# lr 1.000000e-07 reg 3.055556e+04 train accuracy: 0.300449 val accuracy: 0.383000
# lr 1.000000e-07 reg 3.333333e+04 train accuracy: 0.296224 val accuracy: 0.377000
# lr 1.000000e-07 reg 3.611111e+04 train accuracy: 0.292918 val accuracy: 0.370000
# lr 1.000000e-07 reg 3.888889e+04 train accuracy: 0.293347 val accuracy: 0.362000
# lr 1.000000e-07 reg 4.166667e+04 train accuracy: 0.297388 val accuracy: 0.366000
# lr 1.000000e-07 reg 4.444444e+04 train accuracy: 0.286653 val accuracy: 0.356000
# lr 1.000000e-07 reg 4.722222e+04 train accuracy: 0.287061 val accuracy: 0.353000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.287245 val accuracy: 0.352000
# lr 1.444444e-07 reg 2.500000e+04 train accuracy: 0.303000 val accuracy: 0.392000
# lr 1.444444e-07 reg 2.777778e+04 train accuracy: 0.302898 val accuracy: 0.382000
# lr 1.444444e-07 reg 3.055556e+04 train accuracy: 0.303265 val accuracy: 0.383000
# lr 1.444444e-07 reg 3.333333e+04 train accuracy: 0.298388 val accuracy: 0.376000
# lr 1.444444e-07 reg 3.611111e+04 train accuracy: 0.296102 val accuracy: 0.371000
# lr 1.444444e-07 reg 3.888889e+04 train accuracy: 0.293306 val accuracy: 0.359000
# lr 1.444444e-07 reg 4.166667e+04 train accuracy: 0.295041 val accuracy: 0.364000
# lr 1.444444e-07 reg 4.444444e+04 train accuracy: 0.294980 val accuracy: 0.365000
# lr 1.444444e-07 reg 4.722222e+04 train accuracy: 0.292163 val accuracy: 0.360000
# lr 1.444444e-07 reg 5.000000e+04 train accuracy: 0.294347 val accuracy: 0.356000
# lr 1.888889e-07 reg 2.500000e+04 train accuracy: 0.305306 val accuracy: 0.380000
# lr 1.888889e-07 reg 2.777778e+04 train accuracy: 0.296592 val accuracy: 0.382000
# lr 1.888889e-07 reg 3.055556e+04 train accuracy: 0.295102 val accuracy: 0.378000
# lr 1.888889e-07 reg 3.333333e+04 train accuracy: 0.301673 val accuracy: 0.375000
# lr 1.888889e-07 reg 3.611111e+04 train accuracy: 0.297633 val accuracy: 0.371000
# lr 1.888889e-07 reg 3.888889e+04 train accuracy: 0.292122 val accuracy: 0.368000
# lr 1.888889e-07 reg 4.166667e+04 train accuracy: 0.287735 val accuracy: 0.357000
# lr 1.888889e-07 reg 4.444444e+04 train accuracy: 0.285857 val accuracy: 0.344000
# lr 1.888889e-07 reg 4.722222e+04 train accuracy: 0.286408 val accuracy: 0.353000
# lr 1.888889e-07 reg 5.000000e+04 train accuracy: 0.292122 val accuracy: 0.359000
# lr 2.333333e-07 reg 2.500000e+04 train accuracy: 0.313000 val accuracy: 0.401000
# lr 2.333333e-07 reg 2.777778e+04 train accuracy: 0.303673 val accuracy: 0.389000
# lr 2.333333e-07 reg 3.055556e+04 train accuracy: 0.295163 val accuracy: 0.381000
# lr 2.333333e-07 reg 3.333333e+04 train accuracy: 0.297224 val accuracy: 0.363000
# lr 2.333333e-07 reg 3.611111e+04 train accuracy: 0.294020 val accuracy: 0.366000
# lr 2.333333e-07 reg 3.888889e+04 train accuracy: 0.297163 val accuracy: 0.364000
# lr 2.333333e-07 reg 4.166667e+04 train accuracy: 0.292082 val accuracy: 0.372000
# lr 2.333333e-07 reg 4.444444e+04 train accuracy: 0.286694 val accuracy: 0.355000
# lr 2.333333e-07 reg 4.722222e+04 train accuracy: 0.286796 val accuracy: 0.360000
# lr 2.333333e-07 reg 5.000000e+04 train accuracy: 0.278653 val accuracy: 0.350000
# lr 2.777778e-07 reg 2.500000e+04 train accuracy: 0.303224 val accuracy: 0.392000
# lr 2.777778e-07 reg 2.777778e+04 train accuracy: 0.295551 val accuracy: 0.386000
# lr 2.777778e-07 reg 3.055556e+04 train accuracy: 0.297653 val accuracy: 0.370000
# lr 2.777778e-07 reg 3.333333e+04 train accuracy: 0.292184 val accuracy: 0.371000
# lr 2.777778e-07 reg 3.611111e+04 train accuracy: 0.298000 val accuracy: 0.371000
# lr 2.777778e-07 reg 3.888889e+04 train accuracy: 0.299184 val accuracy: 0.370000
# lr 2.777778e-07 reg 4.166667e+04 train accuracy: 0.293816 val accuracy: 0.360000
# lr 2.777778e-07 reg 4.444444e+04 train accuracy: 0.298245 val accuracy: 0.371000
# lr 2.777778e-07 reg 4.722222e+04 train accuracy: 0.292367 val accuracy: 0.360000
# lr 2.777778e-07 reg 5.000000e+04 train accuracy: 0.280939 val accuracy: 0.341000
# lr 3.222222e-07 reg 2.500000e+04 train accuracy: 0.300204 val accuracy: 0.382000
# lr 3.222222e-07 reg 2.777778e+04 train accuracy: 0.304796 val accuracy: 0.397000
# lr 3.222222e-07 reg 3.055556e+04 train accuracy: 0.307286 val accuracy: 0.386000
# lr 3.222222e-07 reg 3.333333e+04 train accuracy: 0.289367 val accuracy: 0.373000
# lr 3.222222e-07 reg 3.611111e+04 train accuracy: 0.299694 val accuracy: 0.373000
# lr 3.222222e-07 reg 3.888889e+04 train accuracy: 0.294020 val accuracy: 0.377000
# lr 3.222222e-07 reg 4.166667e+04 train accuracy: 0.301735 val accuracy: 0.380000
# lr 3.222222e-07 reg 4.444444e+04 train accuracy: 0.283633 val accuracy: 0.356000
# lr 3.222222e-07 reg 4.722222e+04 train accuracy: 0.282796 val accuracy: 0.351000
# lr 3.222222e-07 reg 5.000000e+04 train accuracy: 0.295449 val accuracy: 0.368000
# lr 3.666667e-07 reg 2.500000e+04 train accuracy: 0.302327 val accuracy: 0.385000
# lr 3.666667e-07 reg 2.777778e+04 train accuracy: 0.299612 val accuracy: 0.382000
# lr 3.666667e-07 reg 3.055556e+04 train accuracy: 0.303286 val accuracy: 0.381000
# lr 3.666667e-07 reg 3.333333e+04 train accuracy: 0.294020 val accuracy: 0.373000
# lr 3.666667e-07 reg 3.611111e+04 train accuracy: 0.284776 val accuracy: 0.358000
# lr 3.666667e-07 reg 3.888889e+04 train accuracy: 0.291939 val accuracy: 0.371000
# lr 3.666667e-07 reg 4.166667e+04 train accuracy: 0.290327 val accuracy: 0.366000
# lr 3.666667e-07 reg 4.444444e+04 train accuracy: 0.284041 val accuracy: 0.364000
# lr 3.666667e-07 reg 4.722222e+04 train accuracy: 0.278245 val accuracy: 0.341000
# lr 3.666667e-07 reg 5.000000e+04 train accuracy: 0.294000 val accuracy: 0.358000
# lr 4.111111e-07 reg 2.500000e+04 train accuracy: 0.307122 val accuracy: 0.407000
# lr 4.111111e-07 reg 2.777778e+04 train accuracy: 0.308122 val accuracy: 0.396000
# lr 4.111111e-07 reg 3.055556e+04 train accuracy: 0.298224 val accuracy: 0.374000
# lr 4.111111e-07 reg 3.333333e+04 train accuracy: 0.290082 val accuracy: 0.368000
# lr 4.111111e-07 reg 3.611111e+04 train accuracy: 0.294592 val accuracy: 0.377000
# lr 4.111111e-07 reg 3.888889e+04 train accuracy: 0.296367 val accuracy: 0.379000
# lr 4.111111e-07 reg 4.166667e+04 train accuracy: 0.294939 val accuracy: 0.369000
# lr 4.111111e-07 reg 4.444444e+04 train accuracy: 0.290102 val accuracy: 0.360000
# lr 4.111111e-07 reg 4.722222e+04 train accuracy: 0.289633 val accuracy: 0.353000
# lr 4.111111e-07 reg 5.000000e+04 train accuracy: 0.281531 val accuracy: 0.342000
# lr 4.555556e-07 reg 2.500000e+04 train accuracy: 0.302020 val accuracy: 0.394000
# lr 4.555556e-07 reg 2.777778e+04 train accuracy: 0.299143 val accuracy: 0.389000
# lr 4.555556e-07 reg 3.055556e+04 train accuracy: 0.301673 val accuracy: 0.378000
# lr 4.555556e-07 reg 3.333333e+04 train accuracy: 0.294347 val accuracy: 0.358000
# lr 4.555556e-07 reg 3.611111e+04 train accuracy: 0.297898 val accuracy: 0.373000
# lr 4.555556e-07 reg 3.888889e+04 train accuracy: 0.283041 val accuracy: 0.361000
# lr 4.555556e-07 reg 4.166667e+04 train accuracy: 0.298878 val accuracy: 0.373000
# lr 4.555556e-07 reg 4.444444e+04 train accuracy: 0.285122 val accuracy: 0.351000
# lr 4.555556e-07 reg 4.722222e+04 train accuracy: 0.291653 val accuracy: 0.367000
# lr 4.555556e-07 reg 5.000000e+04 train accuracy: 0.293102 val accuracy: 0.346000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.300490 val accuracy: 0.388000
# lr 5.000000e-07 reg 2.777778e+04 train accuracy: 0.309571 val accuracy: 0.385000
# lr 5.000000e-07 reg 3.055556e+04 train accuracy: 0.308347 val accuracy: 0.385000
# lr 5.000000e-07 reg 3.333333e+04 train accuracy: 0.295265 val accuracy: 0.376000
# lr 5.000000e-07 reg 3.611111e+04 train accuracy: 0.297367 val accuracy: 0.366000
# lr 5.000000e-07 reg 3.888889e+04 train accuracy: 0.295327 val accuracy: 0.372000
# lr 5.000000e-07 reg 4.166667e+04 train accuracy: 0.283429 val accuracy: 0.366000
# lr 5.000000e-07 reg 4.444444e+04 train accuracy: 0.280918 val accuracy: 0.344000
# lr 5.000000e-07 reg 4.722222e+04 train accuracy: 0.289918 val accuracy: 0.353000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.286041 val accuracy: 0.356000
# best validation accuracy achieved during cross-validation: 0.407000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.315000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
